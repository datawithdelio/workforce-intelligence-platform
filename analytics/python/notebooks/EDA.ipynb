# %% [markdown]
# # Workforce Intelligence Platform EDA
#
# This notebook is used to inspect completion-risk features before training.

# %%
from src.features import load_feature_frame
df = load_feature_frame()
df.head()
